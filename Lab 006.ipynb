# %% [markdown]
# # IoT Central

# %% [markdown]
# Nos dirigimos a IoT central
# ![image.png](attachment:8acf7eb3-8f38-40bf-a93d-409d7ededdad.png)

# %% [markdown]
# Ya tenemos nuestro aplicación corriendo
# ![image.png](attachment:46c61e6e-b583-4599-b630-56e017f7cf14.png)

# %% [markdown]
# Nos vamos al dashboard de paneles
# ![image.png](attachment:5f00e5af-ba7b-4fed-9002-bef0c7c87c9b.png)

# %% [markdown]
# Ya estaría, ya podemos crear nosotros mismos nuestro dashboard
